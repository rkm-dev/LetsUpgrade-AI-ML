# %%
import pandas as pd
import matplotlib.pyplot as plt

dataset = pd.read_csv('general_data.csv')

dataset.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   51        No      Travel_Rarely                   Sales                 6
# 1   31       Yes  Travel_Frequently  Research & Development                10
# 2   32        No  Travel_Frequently  Research & Development                17
# 3   38        No         Non-Travel  Research & Development                 2
# 4   32        No      Travel_Rarely  Research & Development                10
#
#    Education EducationField  EmployeeCount  EmployeeID  Gender  ...  \
# 0          2  Life Sciences              1           1  Female  ...
# 1          1  Life Sciences              1           2  Female  ...
# 2          4          Other              1           3    Male  ...
# 3          5  Life Sciences              1           4    Male  ...
# 4          1        Medical              1           5    Male  ...
#
#    NumCompaniesWorked Over18 PercentSalaryHike  StandardHours  \
# ...

# %%
dataset.describe()
# Out:
#                Age  DistanceFromHome    Education  EmployeeCount   EmployeeID  \
# count  4410.000000       4410.000000  4410.000000         4410.0  4410.000000
# mean     36.923810          9.192517     2.912925            1.0  2205.500000
# std       9.133301          8.105026     1.023933            0.0  1273.201673
# min      18.000000          1.000000     1.000000            1.0     1.000000
# 25%      30.000000          2.000000     2.000000            1.0  1103.250000
# 50%      36.000000          7.000000     3.000000            1.0  2205.500000
# 75%      43.000000         14.000000     4.000000            1.0  3307.750000
# max      60.000000         29.000000     5.000000            1.0  4410.000000
#
#           JobLevel  MonthlyIncome  NumCompaniesWorked  PercentSalaryHike  \
# count  4410.000000    4410.000000         4391.000000        4410.000000
# mean      2.063946   65029.312925            2.694830          15.209524
# ...

# %%
dataset[dataset['Attrition']=='Yes'].Age.value_counts().mean()
# Out:
# 18.23076923076923

# %%
dataset['Attrition'].value_counts()
# Out:
# No     3699
# Yes     711
# Name: Attrition, dtype: int64

# %%
dataset.loc[dataset['Attrition'] == 'Yes'].describe()
# Out:
#               Age  DistanceFromHome   Education  EmployeeCount   EmployeeID  \
# count  711.000000        711.000000  711.000000          711.0   711.000000
# mean    33.607595          9.012658    2.877637            1.0  2191.767932
# std      9.675693          7.772368    1.014233            0.0  1270.136654
# min     18.000000          1.000000    1.000000            1.0     2.000000
# 25%     28.000000          2.000000    2.000000            1.0  1072.000000
# 50%     32.000000          7.000000    3.000000            1.0  2165.000000
# 75%     39.000000         15.000000    4.000000            1.0  3341.000000
# max     58.000000         29.000000    5.000000            1.0  4403.000000
#
#          JobLevel  MonthlyIncome  NumCompaniesWorked  PercentSalaryHike  \
# count  711.000000     711.000000          707.000000         711.000000
# mean     2.037975   61682.616034            2.936351          15.481013
# ...

# %%
dataset.loc[dataset['Attrition'] == 'No'].describe()
# Out:
#                Age  DistanceFromHome    Education  EmployeeCount   EmployeeID  \
# count  3699.000000       3699.000000  3699.000000         3699.0  3699.000000
# mean     37.561233          9.227088     2.919708            1.0  2208.139497
# std       8.885956          8.167978     1.025784            0.0  1273.944391
# min      18.000000          1.000000     1.000000            1.0     1.000000
# 25%      31.000000          2.000000     2.000000            1.0  1110.500000
# 50%      36.000000          7.000000     3.000000            1.0  2213.000000
# 75%      43.000000         14.000000     4.000000            1.0  3304.500000
# max      60.000000         29.000000     5.000000            1.0  4410.000000
#
#           JobLevel  MonthlyIncome  NumCompaniesWorked  PercentSalaryHike  \
# count  3699.000000    3699.000000         3684.000000        3699.000000
# mean      2.068938   65672.595296            2.648480          15.157340
# ...

# %% [markdown]
# # Hypothesis 1:
#
#    #### According to the above data the Average age of an employee leaving the company is 34 and the standard deviation is almost 10. So most of the intermediate aged people are looking for another job in some other company, may be they do not fancy the office environment.

# %% [markdown]
# # Hypothesis 2:
#
#    #### The lower job level arround level 2 employees are most quitting, may be they are not getting enough benifits.

# %% [markdown]
# # Hypothesis 3:
#
#    #### People with PercentSalaryHike arround 15 are mostly quitting, may b they are looking for new Jobs with higher increments.

# %% [markdown]
# # Hypothesis 4:
#
#    #### The average salary is arround 61000 of the people who quit compared to the 65000 who stay, so we may need to check on the salary issues with respect to the years of work experience.

# %% [markdown]
# # Hypothesis 5:
#
#    #### People who are quitting are not much in familiar with the current manager as compared to the steady employees, so we might need more interactions between the upper managments and the employees.

# %% [markdown]
# # Hypothesis 6:
#
#    #### Data is showing that people who are fairly new with average of 5 years of job experience are quitting. as compared to the older experienced once, this might be because of less job satisfaction among the attrition group.

# %% [markdown]
# # Hypothesis 7:
#
#    #### The attrition group is also not getting as much promotions as compared to the steady empoyees. So may be that can be looked into.

# %% [markdown]
# # Hypothesis 8:
#
#    #### Attrition data also shows that this group is having people who frequetly change jobs compared to the steady ones. So we need to understand the reason behind it.

# %% [markdown]
# # Hypothesis 9:
#
#    #### Attrition group also have slightly less educated people, may they need more knowledge facilty to jump up in the higher ranks.

# %% [markdown]
# # Hypothesis 10:
#
#    #### Even though the distance between the work place and home is almost equally distributed among the attrition and the non attrition group, we still might find some more observation if we dig a little deeper
