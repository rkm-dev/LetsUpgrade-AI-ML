# %%
import pandas as pd
dataset = pd.read_csv("general_data.csv")

dataset.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   51        No      Travel_Rarely                   Sales                 6
# 1   31       Yes  Travel_Frequently  Research & Development                10
# 2   32        No  Travel_Frequently  Research & Development                17
# 3   38        No         Non-Travel  Research & Development                 2
# 4   32        No      Travel_Rarely  Research & Development                10
#
#    Education EducationField  EmployeeCount  EmployeeID  Gender  ...  \
# 0          2  Life Sciences              1           1  Female  ...
# 1          1  Life Sciences              1           2  Female  ...
# 2          4          Other              1           3    Male  ...
# 3          5  Life Sciences              1           4    Male  ...
# 4          1        Medical              1           5    Male  ...
#
#    NumCompaniesWorked Over18 PercentSalaryHike  StandardHours  \
# ...

# %%
#drop the row with null values 
dataset1=dataset.dropna()

from scipy.stats import pearsonr

#convert Attrition values yes and no as 0 and 1 to be able to correlate and calculate the r value
dataset1.Attrition = dataset1.Attrition.replace('No', 0)
dataset1.Attrition = dataset1.Attrition.replace('Yes', 1)

dataset1.head()
# Out:
# C:\Users\Joy\anaconda3\lib\site-packages\pandas\core\generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
#    Age  Attrition     BusinessTravel              Department  \
# 0   51          0      Travel_Rarely                   Sales
# 1   31          1  Travel_Frequently  Research & Development
# 2   32          0  Travel_Frequently  Research & Development
# 3   38          0         Non-Travel  Research & Development
# 4   32          0      Travel_Rarely  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 0                 6          2  Life Sciences              1           1
# 1                10          1  Life Sciences              1           2
# ...

# %% [markdown]
# ### 1. Correlation between Attrition and Age

# %%
stats,p=pearsonr(dataset1.Attrition, dataset1.Age)
print(stats,p)
# Out:
# -0.15839867954096146 5.126598219398078e-26

# %% [markdown]
# #### Here in the above test we found the correlation between the age and attrition and we got the p-value is less than 0.005 so (h0) is rejected and (ha) is accepted and we can conclude that there is significant correlation between the age and attrition

# %% [markdown]
# ###  2. Next to find the correlation between the Attrition and DistanceFromHome

# %%
stats,p=pearsonr(dataset1.Attrition, dataset1.DistanceFromHome)
print(stats,p)
# Out:
# -0.009448638515156003 0.5317715668019634

# %% [markdown]
# #### The p-value is greater than 0.005 so (h0) is accepted and we can conclude that there is no correlation between the DistanceFromHome and Attrition

# %% [markdown]
# ### 3. Correlation btween Attrition and Education

# %%
stats,p=pearsonr(dataset1.Attrition, dataset1.Education)
print(stats,p)
# Out:
# -0.017106307050278116 0.2575753930816995

# %% [markdown]
# #### Here in the above test we found the correlation between Education and Attrition, the p-value is greater than 0.005 so (h0) is accepted and we can conclude that there is no correlation between the Education and Attrition

# %% [markdown]
# ### 4. Correlation between the Attrition and NumCompaniesWorked

# %%
stats,p=pearsonr(dataset1.Attrition, dataset1.NumCompaniesWorked)
print(stats,p)
# Out:
# 0.04283056724471901 0.004572057121625154

# %% [markdown]
# #### The p-value is less than 0.005 so (h0) is rejected and we can conclude that there is correlation between the NumCompaniesWorked and Attrition.

# %% [markdown]
# ### 5. Correlation between the Attrition and PercentSalaryHike

# %%
stats,p=pearsonr(dataset1.Attrition, dataset1.PercentSalaryHike)
print(stats,p)
# Out:
# 0.03315303713546523 0.028192446935107012

# %% [markdown]
# #### The p-value is greater than 0.005 so (h0) is accepted and we can conclude that there is no correlation between the PercentSalaryHike and Attrition

# %% [markdown]
# ### 6. Correlation between the Attrition and StockOptionLevel

# %%
stats,p=pearsonr(dataset1.Attrition, dataset1.StockOptionLevel)
print(stats,p)
# Out:
# -0.008164026684984027 0.5889996358312328

# %% [markdown]
# #### The p-value is greater than 0.005 so (h0) is accepted and we can conclude that there is no correlation between the StockOptionLevel and Attrition

# %% [markdown]
# ### 7. Correlation between the Attrition and TotalWorkingYears

# %%
stats,p=pearsonr(dataset1.Attrition, dataset1.TotalWorkingYears)
print(stats,p)
# Out:
# -0.1696699168472327 1.1645434967153252e-29

# %% [markdown]
# #### The p-value is less than 0.005 so (h0) is rejected and we can conclude that there is significant correlation between the TotalWorkingYears and Attrition

# %% [markdown]
# ### 8. Correlation between the Attrition and TrainingTimesLastYear

# %%
stats,p=pearsonr(dataset1.Attrition, dataset1.TrainingTimesLastYear)
print(stats,p)
# Out:
# -0.047585736930815525 0.0016276603635481809

# %% [markdown]
# #### The p-value is less than 0.005 so (h0) is rejected and we can conclude that there is correlation between the TrainingTimesLastYear and Attrition

# %% [markdown]
# ### 8. Correlation between the Attrition and YearsAtCompany

# %%
stats,p=pearsonr(dataset1.Attrition, dataset1.YearsAtCompany)
print(stats,p)
# Out:
# -0.13300261842521083 9.476118084864852e-19

# %% [markdown]
# #### The p-value is less than 0.005 so (h0) is rejected and we can conclude that there is correlation between the YearsAtCompany and Attrition

# %% [markdown]
# ### 9. Correlation between the Attrition and YearsSinceLastPromotion

# %%
stats,p=pearsonr(dataset1.Attrition, dataset1.YearsSinceLastPromotion)
print(stats,p)
# Out:
# -0.03142315056330794 0.03752293607393637

# %% [markdown]
# #### The p-value is less than 0.005 so (h0) is rejected and we can conclude that there is correlation between the YearsSinceLastPromotion and Attrition

# %% [markdown]
# ### 10. Correlation between the Attrition and YearsWithCurrManager

# %%
stats,p=pearsonr(dataset1.Attrition, dataset1.YearsWithCurrManager)
print(stats,p)
# Out:
# -0.154691536902868 7.1053696467956645e-25

# %% [markdown]
# #### The p-value is less than 0.005 so (h0) is rejected and we can conclude that there is correlation between the YearsWithCurrManager and Attrition

# %% [markdown]
# ### Correlation Matrix

# %%
dataset1.corr()
# Out:
#                               Age  Attrition  DistanceFromHome  Education  \
# Age                      1.000000  -0.158399          0.007376  -0.033900
# Attrition               -0.158399   1.000000         -0.009449  -0.017106
# DistanceFromHome         0.007376  -0.009449          1.000000  -0.007491
# Education               -0.033900  -0.017106         -0.007491   1.000000
# EmployeeCount                 NaN        NaN               NaN        NaN
# EmployeeID               0.008105  -0.004621         -0.000326  -0.009389
# JobLevel                -0.001137  -0.012382         -0.039990   0.045822
# MonthlyIncome           -0.045163  -0.030160         -0.022757   0.007289
# NumCompaniesWorked       0.299527   0.042831         -0.014449  -0.016210
# PercentSalaryHike       -0.032561   0.033153          0.037720  -0.041054
# StandardHours                 NaN        NaN               NaN        NaN
# StockOptionLevel        -0.031504  -0.008164          0.009353   0.002386
# ...
